# %% [markdown]
# <a href="https://colab.research.google.com/github/jude1997felix/House-price-prediction/blob/main/House_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
test_data = pd.read_csv('/content/drive/MyDrive/house-prices-advanced-regression-techniques/test.csv')
test_data.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
LE = LabelEncoder()
df['MSZoning'] = LE.fit_transform(df['MSZoning'])
df['Street'] = LE.fit_transform(df['Street'])
df.Alley=df.Alley.astype('category').cat.codes
df['Alley'] = LE.fit_transform(df['Alley'])
df['LotShape'] = LE.fit_transform(df['LotShape'])
df['LandContour'] = LE.fit_transform(df['LandContour'])
df['Utilites']=df['Utilites'].astype('category').cat.codes
df['Utilites'] = LE.fit_transform(df['Utilities'])
df['LotConfig'] = LE.fit_transform(df['LotConfig'])
df['LandSlope'] = LE.fit_transform(df['LandSlope'])
df['Neighborhood'] = LE.fit_transform(df['Neighborhood'])
df['Condition1'] = LE.fit_transform(df['Condition1'])
df['Condition2'] = LE.fit_transform(df['Condition2'])
df['BldgType'] = LE.fit_transform(df['BldgType'])
df['HouseStyle'] = LE.fit_transform(df['HouseStyle'])
df['RoofStyle'] = LE.fit_transform(df['RoofStyle'])
df['RoofMatl'] = LE.fit_transform(df['RoofMatl'])
df['Exterior1st'] = LE.fit_transform(df['Exterior1st'])
df['Exterior2nd'] = LE.fit_transform(df['Exterior2nd'])
df.MasVnrType=df.MasVnrType.astype('category').cat.codes
df['MasVnrType'] = LE.fit_transform(df['MasVnrType'])
df['ExterQual'] = LE.fit_transform(df['ExterQual'])
df['ExterCond'] = LE.fit_transform(df['ExterCond'])
df['Foundation'] = LE.fit_transform(df['Foundation'])
df.BsmtQual=df.BsmtQual.astype('category').cat.codes
df['BsmtQual'] = LE.fit_transform(df['BsmtQual'])
df.BsmtCond=df.BsmtCond.astype('category').cat.codes
df['BsmtCond'] = LE.fit_transform(df['BsmtCond'])
df.BsmtExposure=df.BsmtExposure.astype('category').cat.codes
df['BsmtExposure'] = LE.fit_transform(df['BsmtExposure'])
df.BsmtFinType1=df.BsmtFinType1.astype('category').cat.codes
df['BsmtFinType1'] = LE.fit_transform(df['BsmtFinType1'])
df.BsmtFinType2=df.BsmtFinType2.astype('category').cat.codes
df['BsmtFinType2'] = LE.fit_transform(df['BsmtFinType2'])
df['Heating'] = LE.fit_transform(df['Heating'])
df['HeatingQC'] = LE.fit_transform(df['HeatingQC'])
df['CentralAir'] = LE.fit_transform(df['CentralAir'])
df.Electrical=df.Electrical.astype('category').cat.codes
df['Electrical'] = LE.fit_transform(df['Electrical'])
df['KitchenQual'] = LE.fit_transform(df['KitchenQual'])
df['Functional'] = LE.fit_transform(df['Functional'])
df.FireplaceQu=df.FireplaceQu.astype('category').cat.codes
df['FireplaceQu'] = LE.fit_transform(df['FireplaceQu'])
df.GarageType=df.GarageType.astype('category').cat.codes
df['GarageType'] = LE.fit_transform(df['GarageType'])
df.GarageFinish=df.GarageFinish.astype('category').cat.codes
df['GarageFinish'] = LE.fit_transform(df['GarageFinish'])
df.GarageQual=df.GarageQual.astype('category').cat.codes
df['GarageQual'] = LE.fit_transform(df['GarageQual'])
df.GarageCond=df.GarageCond.astype('category').cat.codes
df['GarageCond'] = LE.fit_transform(df['GarageCond'])
df['PavedDrive'] = LE.fit_transform(df['PavedDrive'])
df.PoolQC=df.PoolQC.astype('category').cat.codes
df['PoolQC'] = LE.fit_transform(df['PoolQC'])
df.Fence=df.Fence.astype('category').cat.codes
df['Fence'] = LE.fit_transform(df['Fence'])
df.MiscFeature=df.MiscFeature.astype('category').cat.codes
df['MiscFeature'] = LE.fit_transform(df['MiscFeature'])
df['SaleType'] = LE.fit_transform(df['SaleType'])
df['SaleCondition'] = LE.fit_transform(df['SaleCondition'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Utilites'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-fcd496b7a223> in <module>()
#       6 df['LotShape'] = LE.fit_transform(df['LotShape'])
#       7 df['LandContour'] = LE.fit_transform(df['LandContour'])
# ----> 8 df['Utilites']=df['Utilites'].astype('category').cat.codes
#       9 df['Utilites'] = LE.fit_transform(df['Utilities'])
#      10 df['LotConfig'] = LE.fit_transform(df['LotConfig'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Utilites'

# %%
cols = df.columns
for col in cols:
  print(col,df[col].dtypes)

# %%
df.Alley=df.Alley.astype('category').cat.codes

# %%
df['Alley'] = LE.fit_transform(df['Alley'])
df.Alley.unique()
# Out:
# array([0, 1, 2])
